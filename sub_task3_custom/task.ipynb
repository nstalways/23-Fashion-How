# %% [markdown]
# ## sub-task 3 제출 스크립트
# ETRI FASHION-HOW Season 4 task3 제출코드입니다.
# #### 주의: 반드시 본 파일을 이용하여 제출을 수행해야 하며 파일의 이름은 task.ipynb로 유지되어야 합니다.
# - 작성하신 추론용 코드(예: main.py)를 본 스크립트 내의 etri_task3_submit() 함수로 작동되게끔 삽입하는 것으로 결과 제출을 수행할 수 있습니다.
# - Continual learning을 평가하는 과제로, 6개 데이터셋을 순차적으로 학습한 모델을 업로드하여 각 데이터에 대해 추론을 수행하도록 구성합니다.
#
#
# 코드는 크게 4가지 파트로 구성되며, 해당 파트의 특성을 지켜서 내용을 편집하시면 되겠습니다.
# 1. 제출용 aifactory 라이브러리 설치
# 2. etri_task3_submit() 함수 편집 (추론 스크립트)
# 3. submit() 함수로 wrapping
# 4. if __name__ == "__main__" 조건문을 이용한 제출 수행
#
# ※ 가능하면 제출시에는 포함되어 있는 train data를 폴더에서 제외하고 제출하시는 편이 좋습니다.
# - 파일 크기 감소 → 업로드 시간 감소 → 전체 추론 수행 시간 감소

# %% [markdown]
# ### 1. 제출용 aifactory 라이브러리 설치
# #### 결과 전송에 필요하므로 아래와 같이 aifactory 라이브러리가 반드시 최신버전으로 설치될 수 있게끔 합니다

# %%
# !pip install -U aifactory==1.8.7
# Out:
# Requirement already satisfied: aifactory==1.8.7 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (1.8.7)
# Requirement already satisfied: pipreqs in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from aifactory==1.8.7) (0.4.13)
# Requirement already satisfied: ipynbname in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from aifactory==1.8.7) (2023.2.0.0)
# Requirement already satisfied: gdown in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from aifactory==1.8.7) (4.7.1)
# Requirement already satisfied: requests in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from aifactory==1.8.7) (2.31.0)
# Requirement already satisfied: IPython in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from aifactory==1.8.7) (8.15.0)
# Requirement already satisfied: filelock in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from gdown->aifactory==1.8.7) (3.12.3)
# Requirement already satisfied: six in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from gdown->aifactory==1.8.7) (1.16.0)
# Requirement already satisfied: tqdm in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from gdown->aifactory==1.8.7) (4.66.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from gdown->aifactory==1.8.7) (4.12.2)
# Requirement already satisfied: ipykernel in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipynbname->aifactory==1.8.7) (6.25.2)
# Requirement already satisfied: backcall in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (0.6.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (5.9.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (1.1.3)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from IPython->aifactory==1.8.7) (4.8.0)
# Requirement already satisfied: docopt in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from pipreqs->aifactory==1.8.7) (0.6.2)
# Requirement already satisfied: yarg in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from pipreqs->aifactory==1.8.7) (0.1.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from requests->aifactory==1.8.7) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from requests->aifactory==1.8.7) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from requests->aifactory==1.8.7) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from requests->aifactory==1.8.7) (2023.7.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from jedi>=0.16->IPython->aifactory==1.8.7) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from pexpect>4.3->IPython->aifactory==1.8.7) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->IPython->aifactory==1.8.7) (0.2.6)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from beautifulsoup4->gdown->aifactory==1.8.7) (2.5)
# Requirement already satisfied: typing-extensions>=4.7.1 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from filelock->gdown->aifactory==1.8.7) (4.7.1)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (1.6.7.post1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (5.3.1)
# Requirement already satisfied: nest-asyncio in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (1.5.7)
# Requirement already satisfied: packaging in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (23.1)
# Requirement already satisfied: psutil in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from ipykernel->ipynbname->aifactory==1.8.7) (6.3.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from requests->aifactory==1.8.7) (1.7.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from stack-data->IPython->aifactory==1.8.7) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from stack-data->IPython->aifactory==1.8.7) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from stack-data->IPython->aifactory==1.8.7) (0.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->ipynbname->aifactory==1.8.7) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/envs/fashion_how/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->ipynbname->aifactory==1.8.7) (3.10.0)

# %% [markdown]
# ### 2. etri_task3_submit() 함수 편집 (추론 스크립트)
# #### etri_task3_submit() 편집 시 주의사항
#
# 1. 아래 etri_task3_submit() 함수 내에 전체 추론 실행 코드를 삽입, 6개 테스트셋에 대하여 추론을 6회 수행하고 결과를 list로 묶어 return하게끔 구성
#    - Baseline이 아닌 다른 모델을 사용하는 경우에도 동일
# 2. 함수 내에서는 import * 가 적용되지 않으므로 필요한 import object를 직접 입력
#    - 반드시 함수 내에서 import가 이루어져야 합니다.
# 3. argparse 사용시 args, _ = parser.parse_known_args()로 인자 지정
#    args = parser.parse_args()는 jupyter에서 오류가 발생합니다!!!
# 4. 모델 내부의 경로는 ./ 으로 경로를 지정합니다. (예: weight 파일 경로)
# 5. 데이터는 /aif/data/ 경로 아래에 있습니다. (코드 내용 참조)
#    - subWordEmb_path는 /aif/sstm_v0p5_deploy/ 안에 .dat 파일이 있습니다.
# 6. return할 결과물과 양식에 유의합니다.

# %%
# main.py의 내용을 test 옵션과 제출 후 자동추론 환경에 맞게끔 수정하여 함수화

def etri_task3_submit():
   
    import argparse
    import torch
    from gaia import Model, gAIa
    import os
    cores = os.cpu_count()
    torch.set_num_threads(cores)

    def get_udevice():
        """
        function: get usable devices(CPU and GPU)
        """
        if torch.cuda.is_available():
            device = torch.device('cuda')
            num_gpu = torch.cuda.device_count()
        else:    
            device = torch.device('cpu')
        print('Using device: {}'.format(device))
        if torch.cuda.is_available():
            print('# of GPU: {}'.format(num_gpu))
        return device

    def str2bool(v):
        """
        function: convert into bool type(True or False)
        """
        if isinstance(v, bool): 
            return v 
        if v.lower() in ('yes', 'true', 't', 'y', '1'): 
            return True 
        elif v.lower() in ('no', 'false', 'f', 'n', '0'): 
            return False 
        else: 
            raise argparse.ArgumentTypeError('Boolean value expected.')


    # input options
    parser = argparse.ArgumentParser(description='AI Fashion Coordinator.')

    parser.add_argument('--mode', type=str, 
                        default='pred',
                        help='training or eval or test mode')
    parser.add_argument('--in_file_trn_dialog', type=str, 
                        default='/aif/data/task1.ddata.wst.txt', # 경로 주의
                        help='training dialog DB')
    parser.add_argument('--in_file_tst_dialog', type=str, 
                        default='/aif/data/cl_eval_task1.wst.tst', # 경로 주의 
                        help='test dialog DB')
    parser.add_argument('--in_file_fashion', type=str, 
                        default='/aif/data/mdata.wst.txt.2023.08.23', # 경로 주의 
                        help='fashion item metadata')
    parser.add_argument('--in_file_img_feats', type=str, 
                        default='/aif/data/extracted_feat.json', # 경로 주의 
                        help='fashion item image features')
    parser.add_argument('--model_path', type=str, 
                        default='./gAIa_CL_model', 
                        help='path to save/read model')
    parser.add_argument('--model_file', type=str, 
                        default='gAIa-final_10.pt', 
                        help='model file name')
    parser.add_argument('--eval_node', type=str, 
                        default='[6000,3000,1000,500,200][2000]', 
                        help='nodes of evaluation network')
    parser.add_argument('--subWordEmb_path', type=str, 
                        default='/aif/sstm_v0p5_deploy/sstm_v4p49_np_n36134_d128.dat', # 경로 주의 
                        help='path of subword embedding')
    parser.add_argument('--learning_rate', type=float,
                        default=0.0001, 
                        help='learning rate')
    parser.add_argument('--max_grad_norm', type=float,
                        default=40.0, 
                        help='clip gradients to this norm')
    parser.add_argument('--zero_prob', type=float,
                        default=0.0, 
                        help='dropout prob.')
    parser.add_argument('--corr_thres', type=float,
                        default=0.7, 
                        help='correlation threshold')
    parser.add_argument('--batch_size', type=int,
                        default=100,   
                        help='batch size for training')
    parser.add_argument('--epochs', type=int,
                        default=10,   
                        help='epochs to training')
    parser.add_argument('--save_freq', type=int,
                        default=2,   
                        help='evaluate and save results per # epochs')
    parser.add_argument('--hops', type=int,
                        default=3,   
                        help='number of hops in the MemN2N')
    parser.add_argument('--mem_size', type=int,
                        default=16,   
                        help='memory size for the MemN2N')
    parser.add_argument('--key_size', type=int,
                        default=300,   
                        help='memory size for the MemN2N')
    parser.add_argument('--permutation_iteration', type=int,
                        default=3,   
                        help='# of permutation iteration')
    parser.add_argument('--evaluation_iteration', type=int,
                        default=10,   
                        help='# of test iteration')
    parser.add_argument('--num_augmentation', type=int,
                        default=3,   
                        help='# of data augmentation')
    parser.add_argument('--use_batch_norm', type=str2bool, 
                        default=False, 
                        help='use batch normalization')
    parser.add_argument('--use_dropout', type=str2bool, 
                        default=False, 
                        help='use dropout')
    parser.add_argument('--use_multimodal', type=str2bool,
                        default=False, 
                        help='use multimodal input')
    parser.add_argument('--use_cl', type=str2bool,
                        default=True,
                        help='enable continual learning')

    args, _ = parser.parse_known_args()
    
    # 테스트 파일 경로를 바꿔가면서 6회의 로드와 추론을 수행
    # 다른 모델을 사용하는 경우에도 6회의 추론이 수행되어야 함에 유의
    out = [] # 각 예측 결과를 리스트 형태로 묶어서 리턴
    for i in range(1, 7):
        args.in_file_tst_dialog = f'/aif/data/cl_eval_task{i}.wst.dev' # 경로에 주의
        gaia = gAIa(args, get_udevice()) # 베이스라인의 경우 argument가 적용되는 구조상 매 추론마다의모델을 새로 로드해야함에 유의
        out.append(gaia.pred())    
    
    return out

# %% [markdown]
# ### 3. submit() 함수로 wrapping
# #### 반드시 아래와 같이 submit() 이라는 함수로 위에 정의된 etri_task3_submit 함수를 wrapping해야 합니다.

# %%
def submit():
    return etri_task3_submit

# %% [markdown]
# ### 4. if name == "main" 조건문을 이용한 제출 수행
# #### 아래와 같이 if __name__ == "__main__" 구문 내에서 제출 함수가 실행되게끔 합니다.
# #### ※ task별, 참가자별로 key가 다릅니다. 잘못 입력하지 않도록 유의바랍니다.
# - key는 각팀 팀장분에게 메일로 할당된 계정을 이용하여 task별로 확인하실 수 있습니다.

# %%
import aifactory.score as aif
import time
t = time.time()
if __name__ == "__main__":
    #-----------------------------------------------------#
    aif.submit(model_name="gAIa-final_10.pt",
               key="2b6d9e1d-a527-4490-908c-7c020cca4605",
               func=submit # submit function
               )
    #-----------------------------------------------------#
    print(time.time() - t)
# Out:
# file : task.py
# python
# 파일 전송 완료
# error = L_SW-270 doesn't exist.
# 303.4178538322449
